# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import altair as alt

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_csv('SBAnational.csv')
df.head(1)
# Out:
# /var/folders/d3/6_5r7d716cb8gqs9y4qft_600000gp/T/ipykernel_29003/2675700227.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('SBAnational.csv')
#    LoanNr_ChkDgt            Name        City State    Zip              Bank  \
# 0     1000014003  ABC HOBBYCRAFT  EVANSVILLE    IN  47711  FIFTH THIRD BANK
#
#   BankState   NAICS ApprovalDate ApprovalFY  Term  NoEmp  NewExist  CreateJob  \
# 0        OH  451120    28-Feb-97       1997    84      4       2.0          0
#
#    RetainedJob  FranchiseCode  UrbanRural RevLineCr LowDoc ChgOffDate  \
# 0            0              1           0         N      Y        NaN
#
#   DisbursementDate DisbursementGross BalanceGross MIS_Status ChgOffPrinGr  \
# 0        28-Feb-99       $60,000.00        $0.00       P I F       $0.00
#
#         GrAppv     SBA_Appv
# 0  $60,000.00   $48,000.00

# %%
# visualizations dataframe
df['DisbursementGross'] = df['DisbursementGross'].replace('[\$,]', '', regex=True).astype(float)
df['GrAppv'] = df['GrAppv'].replace('[\$,]', '', regex=True).astype(float)
df['SBA_Appv'] = df['SBA_Appv'].replace('[\$,]', '', regex=True).astype(float)
# clean 'ApprovalFY' column by removing non-numeric characters and converting to int
df['SBA_Appv'] = df['ApprovalFY'].astype(str).str.extract('(\d+)').astype(int)
df.head(1)
# Out:
#    LoanNr_ChkDgt            Name        City State    Zip              Bank  \
# 0     1000014003  ABC HOBBYCRAFT  EVANSVILLE    IN  47711  FIFTH THIRD BANK
#
#   BankState   NAICS ApprovalDate ApprovalFY  Term  NoEmp  NewExist  CreateJob  \
# 0        OH  451120    28-Feb-97       1997    84      4       2.0          0
#
#    RetainedJob  FranchiseCode  UrbanRural RevLineCr LowDoc ChgOffDate  \
# 0            0              1           0         N      Y        NaN
#
#   DisbursementDate  DisbursementGross BalanceGross MIS_Status ChgOffPrinGr  \
# 0        28-Feb-99            60000.0       $0.00       P I F       $0.00
#
#     GrAppv  SBA_Appv
# 0  60000.0      1997

# %%
import geopandas
state = geopandas.read_file('ne_110m_admin_1_states_provinces')

# manipulate string data to match the loan dataset, so instead of US-MN, it will be MN, for Minnesota etc
state['iso_3166_2'] = state['iso_3166_2'].str.replace('US-', '')

state.head(1)
# Out:
#            featurecla  scalerank adm1_code  diss_me iso_3166_2  \
# 0  Admin-1 scale rank          2  USA-3514     3514         MN
#
#                                 wikipedia iso_a2  adm0_sr       name  \
# 0  http://en.wikipedia.org/wiki/Minnesota     US        1  Minnesota
#
#    name_alt name_local   type type_en code_local code_hasc  note hasc_maybe  \
# 0  MN|Minn.       None  State   State       US27     US.MN  None       None
#
#     region region_cod  provnum_ne  gadm_level  check_me  datarank abbrev  \
# 0  Midwest       None           0           1        20         1  Minn.
#
#   postal  area_sqkm  sameascity  labelrank  name_len  mapcolor9  mapcolor13  \
# 0     MN          0         -99          0         9          1           1
#
#    fips fips_alt   woe_id                     woe_label   woe_name  latitude  \
# 0  US27     None  2347582  Minnesota, US, United States  Minnesota   46.0592
#
#    longitude sov_a3 adm0_a3  adm0_label                     admin  \
# 0    -93.364    US1     USA           2  United States of America
#
#                    geonunit gu_a3    gn_id    gn_name  gns_id gns_name  \
# 0  United States of America   USA  5037779  Minnesota      -1     None
#
#    gn_level gn_region gn_a1_code          region_sub sub_code  gns_level  \
# 0         1      None      US.MN  West North Central     None         -1
#
#   gns_lang gns_adm1 gns_region  min_label  max_label  min_zoom wikidataid  \
# 0     None     None       None        3.5        7.5         2      Q1527
#
#     name_ar   name_bn    name_de    name_en    name_es    name_fr   name_el  \
# 0  مينيسوتا  মিনেসোটা  Minnesota  Minnesota  Minnesota  Minnesota  Μινεσότα
#
#     name_hi    name_hu    name_id    name_it name_ja name_ko    name_nl  \
# 0  मिनेसोटा  Minnesota  Minnesota  Minnesota   ミネソタ州    미네소타  Minnesota
#
#      name_pl    name_pt    name_ru    name_sv    name_tr    name_vi name_zh  \
# 0  Minnesota  Minnesota  Миннесота  Minnesota  Minnesota  Minnesota   明尼苏达州
#
#         ne_id  name_he    name_uk   name_ur   name_fa name_zht FCLASS_ISO  \
# 0  1159315297  מינסוטה  Міннесота  مینیسوٹا  مینهسوتا    明尼蘇達州       None
#
#   FCLASS_US FCLASS_FR FCLASS_RU FCLASS_ES FCLASS_CN FCLASS_TW FCLASS_IN  \
# 0      None      None      None      None      None      None      None
#
#   FCLASS_NP FCLASS_PK FCLASS_DE FCLASS_GB FCLASS_BR FCLASS_IL FCLASS_PS  \
# 0      None      None      None      None      None      None      None
#
#   FCLASS_SA FCLASS_EG FCLASS_MA FCLASS_PT FCLASS_AR FCLASS_JP FCLASS_KO  \
# 0      None      None      None      None      None      None      None
#
#   FCLASS_VN FCLASS_TR FCLASS_ID FCLASS_PL FCLASS_GR FCLASS_IT FCLASS_NL  \
# 0      None      None      None      None      None      None      None
#
#   FCLASS_SE FCLASS_BD FCLASS_UA FCLASS_TLC  \
# 0      None      None      None       None
#
#                                             geometry
# 0  POLYGON ((-89.95766 47.28691, -90.13175 47.292...

# %%
merged_init = pd.merge(df, state, left_on='State', right_on='iso_3166_2')

# selecting all columns up to and including 'region'
region_col_index = merged_init.columns.get_loc('region') + 1  # +1 to include 'region' column itself
merged_up_to_region = merged_init.iloc[:, :region_col_index]

# selecting the geometry column
merged_geometry = merged_init[['geometry']]

# concatenating the parts to get the final DataFrame
merged_final = pd.concat([merged_up_to_region, merged_geometry], axis=1)

# dropping final rows that are not needed now that data is aggregated
merged_final = merged_final.drop(columns=['hasc_maybe', 'code_hasc', 'type_en', 'name_local', 'name_alt', 'adm0_sr', 'iso_a2', 
                                          'wikipedia', 'diss_me', 'scalerank', 'featurecla', 'note', 'code_local'])

merged_final.head(1)
# Out:
#    LoanNr_ChkDgt            Name        City State    Zip              Bank  \
# 0     1000014003  ABC HOBBYCRAFT  EVANSVILLE    IN  47711  FIFTH THIRD BANK
#
#   BankState   NAICS ApprovalDate ApprovalFY  Term  NoEmp  NewExist  CreateJob  \
# 0        OH  451120    28-Feb-97       1997    84      4       2.0          0
#
#    RetainedJob  FranchiseCode  UrbanRural RevLineCr LowDoc ChgOffDate  \
# 0            0              1           0         N      Y        NaN
#
#   DisbursementDate  DisbursementGross BalanceGross MIS_Status ChgOffPrinGr  \
# 0        28-Feb-99            60000.0       $0.00       P I F       $0.00
#
#     GrAppv  SBA_Appv adm1_code iso_3166_2     name   type   region  \
# 0  60000.0      1997  USA-3547         IN  Indiana  State  Midwest
#
#                                             geometry
# 0  POLYGON ((-88.05108 37.81960, -88.01881 38.021...

# %%
# making industry column with first two digits of NAICS
merged_industry = merged_final.copy()
merged_industry['NAICS'] = merged_industry['NAICS'].astype(str)
merged_industry['Industry'] = merged_industry['NAICS'].str[:2]


merged_industry.head(1)
# Out:
#    LoanNr_ChkDgt            Name        City State    Zip              Bank  \
# 0     1000014003  ABC HOBBYCRAFT  EVANSVILLE    IN  47711  FIFTH THIRD BANK
#
#   BankState   NAICS ApprovalDate ApprovalFY  Term  NoEmp  NewExist  CreateJob  \
# 0        OH  451120    28-Feb-97       1997    84      4       2.0          0
#
#    RetainedJob  FranchiseCode  UrbanRural RevLineCr LowDoc ChgOffDate  \
# 0            0              1           0         N      Y        NaN
#
#   DisbursementDate  DisbursementGross BalanceGross MIS_Status ChgOffPrinGr  \
# 0        28-Feb-99            60000.0       $0.00       P I F       $0.00
#
#     GrAppv  SBA_Appv adm1_code iso_3166_2     name   type   region  \
# 0  60000.0      1997  USA-3547         IN  Indiana  State  Midwest
#
#                                             geometry Industry
# 0  POLYGON ((-88.05108 37.81960, -88.01881 38.021...       45

# %%
# moving column to next to NAICS
columns = list(merged_industry.columns)

columns.remove('Industry')

target_index = columns.index('NAICS') + 1  
columns.insert(target_index, 'Industry')

merged_industry = merged_industry[columns]

merged_industry.head(1)
# Out:
#    LoanNr_ChkDgt            Name        City State    Zip              Bank  \
# 0     1000014003  ABC HOBBYCRAFT  EVANSVILLE    IN  47711  FIFTH THIRD BANK
#
#   BankState   NAICS Industry ApprovalDate ApprovalFY  Term  NoEmp  NewExist  \
# 0        OH  451120       45    28-Feb-97       1997    84      4       2.0
#
#    CreateJob  RetainedJob  FranchiseCode  UrbanRural RevLineCr LowDoc  \
# 0          0            0              1           0         N      Y
#
#   ChgOffDate DisbursementDate  DisbursementGross BalanceGross MIS_Status  \
# 0        NaN        28-Feb-99            60000.0       $0.00       P I F
#
#   ChgOffPrinGr   GrAppv  SBA_Appv adm1_code iso_3166_2     name   type  \
# 0       $0.00   60000.0      1997  USA-3547         IN  Indiana  State
#
#     region                                           geometry
# 0  Midwest  POLYGON ((-88.05108 37.81960, -88.01881 38.021...

# %%
# map NAISC to industry

industry_map = {
  '11': 'Ag/For/Fish/Hunt',
  '21': 'Min/Quar/Oil_Gas_ext',
  '22': 'Utilities',
  '23': 'Construction',
  '31': 'Manufacturing',
  '32': 'Manufacturing',
  '33': 'Manufacturing',
  '42': 'Wholesale_trade',
  '44': 'Retail_trade',
  '45': 'Retail_trade',
  '48': 'Trans/Ware',
  '49': 'Trans/Ware',
  '51': 'Information',
  '52': 'Finance/Insurance',
  '53': 'RE/Rental/Lease',
  '54': 'Prof/Science/Tech',
  '55': 'Mgmt_comp',
  '56': 'Admin_sup/Waste_Mgmt_Rem',
  '61': 'Educational',
  '62': 'Healthcare/Social_assist',
  '71': 'Arts/Entertain/Rec',
  '72': 'Accom/Food_serv',
  '81': 'Other_no_pub',
  '92': 'Public_Admin'
}

merged_industry['Industry'] = merged_industry['Industry'].map(industry_map)

# %%
# making sure industry works
merged_industry.head()

# export_csv_df = merged_industry.to_csv('exported.csv', index=False)
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS                  Industry  \
# 0               FIFTH THIRD BANK        OH  451120              Retail_trade
# 1                1ST SOURCE BANK        IN  722410           Accom/Food_serv
# 2        GRANT COUNTY STATE BANK        IN  621210  Healthcare/Social_assist
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0                       NaN
# 4        FLORIDA BUS. DEVEL CORP        FL       0                       NaN
#
#   ApprovalDate ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 0    28-Feb-97       1997    84      4       2.0          0            0
# 1    28-Feb-97       1997    60      2       2.0          0            0
# 2    28-Feb-97       1997   180      7       1.0          0            0
# 3    28-Feb-97       1997    60      2       1.0          0            0
# 4    28-Feb-97       1997   240     14       1.0          7            7
#
#    FranchiseCode  UrbanRural RevLineCr LowDoc ChgOffDate DisbursementDate  \
# 0              1           0         N      Y        NaN        28-Feb-99
# 1              1           0         N      Y        NaN        31-May-97
# 2              1           0         N      N        NaN        31-Dec-97
# 3              1           0         N      Y        NaN        30-Jun-97
# 4              1           0         N      N        NaN        14-May-97
#
#    DisbursementGross BalanceGross MIS_Status ChgOffPrinGr    GrAppv  SBA_Appv  \
# 0            60000.0       $0.00       P I F       $0.00    60000.0      1997
# 1            40000.0       $0.00       P I F       $0.00    40000.0      1997
# 2           287000.0       $0.00       P I F       $0.00   287000.0      1997
# 3            35000.0       $0.00       P I F       $0.00    35000.0      1997
# 4           229000.0       $0.00       P I F       $0.00   229000.0      1997
#
#   adm1_code iso_3166_2      name   type   region  \
# 0  USA-3547         IN   Indiana  State  Midwest
# 1  USA-3547         IN   Indiana  State  Midwest
# 2  USA-3547         IN   Indiana  State  Midwest
# 3  USA-3533         OK  Oklahoma  State    South
# 4  USA-3542         FL   Florida  State    South
#
#                                             geometry
# 0  POLYGON ((-88.05108 37.81960, -88.01881 38.021...
# 1  POLYGON ((-88.05108 37.81960, -88.01881 38.021...
# 2  POLYGON ((-88.05108 37.81960, -88.01881 38.021...
# 3  POLYGON ((-103.00322 36.99516, -102.04118 36.9...
# 4  POLYGON ((-87.53039 30.27420, -87.45789 30.411...

# %%
# Convert NAICS codes to numeric, setting errors='coerce' to turn invalid values into NaN
merged_industry['NAICS'] = pd.to_numeric(merged_industry['NAICS'], errors='coerce')

# Filter out entries with invalid (NaN) or 0 NAICS codes
filtered_df = merged_industry[merged_industry['NAICS'].notna() & (merged_industry['NAICS'] != 0)]

# Now, find the most common NAICS code for each state in the filtered DataFrame
most_common_naics = filtered_df.groupby('State')['NAICS'].agg(lambda x: x.value_counts().idxmax()).reset_index(name='Most_Common_NAICS')

most_common_naics['Industry'] = most_common_naics['Most_Common_NAICS'].astype(str).str[:2].map(industry_map)

most_common_naics.head()
# Out:
#   State  Most_Common_NAICS                  Industry
# 0    AK             114111          Ag/For/Fish/Hunt
# 1    AL             722110           Accom/Food_serv
# 2    AR             112320          Ag/For/Fish/Hunt
# 3    AZ             621210  Healthcare/Social_assist
# 4    CA             722110           Accom/Food_serv

# %%
filtered_df['ChgOffPrinGr'].fillna(0, inplace=True)
# Ensure the relevant columns are numeric
filtered_df['GrAppv'] = pd.to_numeric(filtered_df['GrAppv'], errors='coerce')
filtered_df['DisbursementGross'] = pd.to_numeric(filtered_df['DisbursementGross'], errors='coerce')
filtered_df['ChgOffPrinGr'] = pd.to_numeric(filtered_df['ChgOffPrinGr'], errors='coerce')

# Calculate average approval, disbursement, and charge off amounts per state
avg_values = filtered_df.groupby('State').agg(
    Avg_Approval=('GrAppv', 'mean'),
    Avg_Disbursement=('DisbursementGross', 'mean'),
    Avg_ChargeOff=('ChgOffPrinGr', 'mean')
).reset_index()

# Merge the average values with the most_common_naics DataFrame
enhanced_df = pd.merge(most_common_naics, avg_values, on='State')

# Display the first few rows of the enhanced DataFrame
enhanced_df.head()
# Out:
# /var/folders/d3/6_5r7d716cb8gqs9y4qft_600000gp/T/ipykernel_29003/818893386.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['ChgOffPrinGr'].fillna(0, inplace=True)
# /var/folders/d3/6_5r7d716cb8gqs9y4qft_600000gp/T/ipykernel_29003/818893386.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['GrAppv'] = pd.to_numeric(filtered_df['GrAppv'], errors='coerce')
# /var/folders/d3/6_5r7d716cb8gqs9y4qft_600000gp/T/ipykernel_29003/818893386.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['DisbursementGross'] = pd.to_numeric(filtered_df['DisbursementGross'], errors='coerce')
# /var/folders/d3/6_5r7d716cb8gqs9y4qft_600000gp/T/ipykernel_29003/818893386.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['ChgOffPrinGr'] = pd.to_numeric(filtered_df['ChgOffPrinGr'], errors='coerce')
#   State  Most_Common_NAICS                  Industry   Avg_Approval  \
# 0    AK             114111          Ag/For/Fish/Hunt  212978.445974
# 1    AL             722110           Accom/Food_serv  210758.002843
# 2    AR             112320          Ag/For/Fish/Hunt  188759.533891
# 3    AZ             621210  Healthcare/Social_assist  240089.299305
# 4    CA             722110           Accom/Food_serv  251202.443857
#
#    Avg_Disbursement  Avg_ChargeOff
# 0     218077.534067            NaN
# 1     212037.262129            NaN
# 2     191896.636692            NaN
# 3     254711.688837            NaN
# 4     259223.004847            NaN

# %%
industry_colors = {
    'Ag/For/Fish/Hunt': '#9932cc',
    'Min/Quar/Oil_Gas_ext': '#1f78b4',
    'Utilities': '#b2df8a',
    'Construction': '#33a02c',
    'Manufacturing': '#fb9a99',
    'Wholesale_trade': '#e31a1c',
    'Retail_trade': '#fdbf6f',
    'Trans/Ware': '#ff7f00',
    'Information': '#40e0d0',
    'Finance/Insurance': '#6a3d9a',
    'RE/Rental/Lease': '#ffff99',
    'Prof/Science/Tech': '#b15928',
    'Mgmt_comp': '#b5a2ca',
    'Admin_sup/Waste_Mgmt_Rem': '#9acd32',
    'Educational': '#e31a1c',
    'Healthcare/Social_assist': '#008000',
    'Arts/Entertain/Rec': '#daa520',
    'Accom/Food_serv': '#d2691e',
    'Other_no_pub': '#ffffb3',
    'Public_Admin': '#ff00ff'
}

# %%
import folium

# Function to return the style dictionary with black borders
def get_style_function(fill_color):
    def style_function(feature):
        return {
            'fillColor': fill_color,
            'color': '#000000',  # Set border color to black
            'fillOpacity': 0.5,
            'weight': 1,  # Border line weight
        }
    return style_function


merged_gdf = state.merge(most_common_naics, left_on='iso_3166_2', right_on='State')

# create the Folium map
m = folium.Map(location=[45, -95], zoom_start=4)

industry_groups = {}

for _, row in merged_gdf.iterrows():
    state_geo = row['geometry']
    state_name = row['name']
    industry = row['Industry']
    naics_code = row['Most_Common_NAICS']
    color = industry_colors.get(industry, '#000000')  # Set color, default to black if missing

    # check if the FG for this industry already exists; if not, create it
    if industry not in industry_groups:
        industry_groups[industry] = folium.FeatureGroup(name=industry).add_to(m)

    # create a GeoJson for the state and add it to the appropriate FG
    folium.GeoJson(
        state_geo,
        style_function=get_style_function(color),
        tooltip=f"State: {state_name} <br> Industry: {industry}",
        popup=folium.Popup(f"State: {state_name}<br>NAICS: {naics_code}<br>Industry: {industry}", max_width=300) # change popup info to more relevan stuff!
    ).add_to(industry_groups[industry])

#  LayerControl to the map
m.add_child(folium.LayerControl())

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cc829462e4331b8823ee546f98351ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cc829462e4331b8823ee546f98351ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cc829462e4331b8823ee546f98351ca = L.map(
#                 &quot;map_1cc829462e4331b8823ee546f98351ca&quot;,
#                 {
#                     center: [45.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cde37d9c8755b7b2762bf7bc09cac3b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cde37d9c8755b7b2762bf7bc09cac3b2.addTo(map_1cc829462e4331b8823ee546f98351ca);
#
#
#             var feature_group_46d53ed641c9536c7f741c1ce8f73a33 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_24316c58549c5051c45959995631d053_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#000000&quot;, &quot;fillColor&quot;: &quot;#d2691e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_24316c58549c5051c45959995631d053_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_24316c58549c5051c45959995631d053 = L.geoJson(null, {
#                 onEachFeature: geo_json_24316c58549c5051c45959995631d053_onEachFeature,
#
#                 style: geo_json_24316c58549c5051c45959995631d053_styler,
#         });
#
#         function geo_json_24316c58549c5051c45959995631d053_add (data) {
#             geo_json_24316c58549c5051c45959995631d053
#                 .addData(data);
#         }
#             geo_json_24316c58549c5051c45959995631d053_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-89.95765601272012, 47.286907253603175], [-90.13175391311144, 47.29274669045216], [-90.30585181350276, 47.29801768654593], [-90.47994971389409, 47.30385712339489], [-90.6540476142854, 47.309128119488676], [-90.85778194859611, 47.21282908791278], [-91.06097368036777, 47.117046820659795], [-91.26470801467849, 47.02126455340681], [-91.46844234898919, 46.9249655218309], [-91.59225908076053, 46.876260484395914], [-91.71661841507091, 46.82760712339301], [-91.8409777493813, 46.778385321635], [-91.96479448115262, 46.72970612241605], [-92.01189754918667, 46.71172272397848], [-92.27487891312, 46.65614472104858], [-92.26482784703924, 46.09522288673644], [-92.2965830146826, 46.09628225359842], [-92.54369971390233, 45.98569468849381], [-92.75696834997089, 45.88991242124082], [-92.89982784704182, 45.705763454768714], [-92.68922054723626, 45.51843638771068], [-92.76541744665064, 45.26708222104298], [-92.76647681351261, 44.9961426865367], [-92.79665584997105, 44.77602692318949], [-92.50507158076417, 44.58391978614445], [-92.38549231644078, 44.57492808692567], [-92.06215287959051, 44.43258535417769], [-91.949989183301, 44.364837551443046], [-91.87960588251947, 44.25742808692439], [-91.62770911331273, 44.085448920257036], [-91.28959021682704, 43.93729258887629], [-91.25729244664458, 43.854739488289965], [-91.2546569485977, 43.61397899024206], [-91.22819861526426, 43.5012468531974], [-92.54000484899348, 43.51977285417405], [-94.00102678096546, 43.51341665300214], [-95.35993608272871, 43.50018748633542], [-96.4526600817565, 43.50178945573647], [-96.43943091508982, 44.43576345476367], [-96.56061214881424, 45.39301768653837], [-96.73576941606754, 45.47081655535372], [-96.83470394569034, 45.62532908790642], [-96.78072791216147, 45.76079885515958], [-96.55689144568922, 45.87244578712617], [-96.53945064979075, 46.017966620460186], [-96.53890804725165, 46.199480088885366], [-96.60135901567638, 46.3513571233911], [-96.68548824744755, 46.51328522397769], [-96.73365068234358, 46.71647695574927], [-96.7458204821483, 46.9445250514533], [-96.77969438351563, 46.999043687521294], [-96.82041541216165, 47.29220408791309], [-96.82465287960957, 47.42661448830425], [-96.84423824744819, 47.54619375262766], [-96.89397681352912, 47.74886872007637], [-97.01515804725355, 47.954205023788134], [-97.13104244666809, 48.13729462339825], [-97.14850908078273, 48.31878225360731], [-97.16122148312654, 48.51458425556122], [-97.12734758175921, 48.64212169045756], [-97.1204746162644, 48.75852285419501], [-97.21413814979343, 48.90244171812793], [-97.22894344764504, 49.00088532164389], [-95.15883724646483, 48.9998259547819], [-95.15620174841791, 49.38401439065592], [-94.81754024939323, 49.38928538674975], [-94.64026424841592, 48.84001658791925], [-94.32912044958647, 48.670672919298795], [-93.63061011429733, 48.60928131773602], [-92.60984554723586, 48.45001455341253], [-91.63987891311746, 48.13993012144516], [-90.83026424840062, 48.27010305438836], [-89.59995174839577, 48.01027395282483], [-89.5994091458566

# %%
# make a model to check most relevant features that predict discharge (defaulting on loan) and then make some type of regression and then make scatterplot 
# --> Make a static visualization to show relationships --> maps and altair visualizations to show geografically where it is most occuring and by industry/location/size
# make an altair viz to interact with different factors to see how likely it is to dissaprov/approv/default/etc

# %%
import altair as alt

sampled_df = merged_industry.sample(n=1000, random_state=1)  # random_state ensures reproducibility

# Create a sample DataFrame without the complex data types
sampled_df_cleaned = sampled_df.drop(columns=['geometry'])  # Assuming 'geometry' is the column with Polygon objects

# Now, use this cleaned DataFrame for your Altair chart
# Ensure the DataFrame contains only the columns you'll use for the visualization
input_dropdown = alt.binding_select(options=['Industry', 'Region'])
selection = alt.selection_single(fields=['category'], bind=input_dropdown, name='View By')

# Base chart for charge-offs using the cleaned sampled DataFrame
base_chart = alt.Chart(sampled_df_cleaned).mark_bar().encode(
    x=alt.X('sum(ChgOffPrinGr):Q', title='Total Charge Off'),
    y=alt.Y('category:N', sort='-x'),
    color=alt.condition(selection, alt.Color('category:N', legend=None), alt.value('lightgray')),
    tooltip=[alt.Tooltip('category:N'), alt.Tooltip('sum(ChgOffPrinGr):Q', title='Total Charge Off')]
).add_params(
    selection
).transform_fold(
    fold=['Industry', 'Region'], as_=['category', 'value']
).transform_filter(
    selection
)

# Display the chart
base_chart.properties(width=600, height=400)
# Out:
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_single' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# /Users/maximizosimov/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)
